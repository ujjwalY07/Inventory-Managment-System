# %%
products = {"1001": {"name": "Colgate visible white", "price": 240, "quan": 76, "expiry": "19 jul 2024", "brand": "Colgate"}, "1002": {"name": "Pepsodent Gum Care", "price": 170, "quan": 190, "expiry": "29 sep 2023", "brand": "Pepsodent"}, "1003": {"name": "Dabur Honey", "price": 210, "quan": 140, "expiry": "15 mar 2024", "brand": "DABUR"}, "1004": {"name": "Nivea Men's Face Wash", "price": 149, "quan": 99, "expiry": "17 aug 2022", "brand": "Nivea"}, "1005": {"name": "Himalaya Herbal Face wash", "price": 90, "quan": 206, "expiry": "26 jul 2022", "brand": "Himalaya"}, "1006": {"name": "johnson's Baby Powder", "price": 189, "quan": 130, "expiry": "30 aug 2024", "brand": "johnson's"}, "1007": {"name": "Nivea lotion", "price": 135, "quan": 95, "expiry": "13 mar 2024", "brand": "Nivea"}, "1008": {"name": "Fogg Scent", "price": 259, "quan": 104, "expiry": "10 jan 2024", "brand": "FOGG"}, "1009": {"name": "Villain Perfume men's", "price": 440, "quan": 90, "expiry": "10 oct 2023", "brand": "Villain"}, "1010": {"name": "Dairy Milk Silk", "price": 120, "quan": 55, "expiry": "4 feb 2022", "brand": "Cadbury"}, "1011": {"name": "Kitkat Desert", "price": 70, "quan": 46, "expiry": "14 sep 2022", "brand": "Nestle"}, "1012": {"name": "Dark Fantasy Choco Fills", "price": 60, "quan": 70, "expiry": "21 feb 2022", "brand": "Sunfeast"}, "1013": {"name": "Haldiram's bhelpuri", "price": 60, "quan": 80, "expiry": "18 jan 2022", "brand": "Haldiram's"}, "1014": {"name": "Lotte Choco Pie", "price": 100, "quan": 60, "expiry": "7 jun 2022", "brand": "Lotte"}, "1015": {"name": "Britania Chocolate cake", "price": 100, "quan": 110, "expiry": "19 jun 2022", "brand": "Britania"}, "1016": {"name": "Pillsbury cookies cake", "price": 90, "quan": 160, "expiry": "06 dec 2021", "brand": "Pillsbury"}, "1017": {"name": "Oreo Biscuit's", "price": 35, "quan": 170, "expiry": "26 jan 2022", "brand": "Oreo"}, "1018": {"name": "Mom's Magic Cashew", "price": 80, "quan": 180, "expiry": "19 mar 2022", "brand": "Sunfeast"}, "1019": {"name": "Cadbury Oreo chacolate", "price": 60, "quan": 140, "expiry": "13 jan 2022", "brand": "Cadbury"}, "1020": {"name": "winky's swissroll", "price": 55, "quan": 83, "expiry": "4 jan 2022", "brand": "winky's"}, "1021": {"name": "Parle G Original", "price": 66, "quan": 140, "expiry": "13 dec 2011", "brand": "Parle"}, "1022": {"name": "Lays Potato Chips", "price": 35, "quan": 110, "expiry": "14 feb 2023", "brand": "Lay's"}, "1023": {"name": "Bingo! Mad Angle's", "price": 20, "quan": 140, "expiry": "23 dec 2023", "brand": "Bingo!"}, "1024": {"name": "Kellogg's corn-flakes", "price": 90, "quan": 100, "expiry": "27 nov 2023", "brand": "Kellog's"}, "1025": {"name": "Nacho Chips", "price": 60, "quan": 130, "expiry": "15 aug 2023", "brand": "Dorito"}, "1026": {"name": "Thums Up Soft Drink", "price": 40, "quan": 74, "expiry": "23 jul 2023", "brand": "Thums Up"}, "1027": {"name": "Soda Water", "price": 55, "quan": 40, "expiry": "29 feb 2023", "brand": "Rajj"}, "1028": {"name": "Coca-Cola", "price": 45, "quan": 99, "expiry": "7 jul 2023", "brand": "Coca Cola"}, "1029": {"name": "Sprite Lime Flavor", "price": 50, "quan": 46, "expiry": "20 oct 2023", "brand": "Sprite"}, "1030": {"name": "Pepsi Can", "price": 110, "quan": 65, "expiry": "20 apr 2022", "brand": "Pepsi"}, "1031": {"name": "Tata Salt", "price": 22, "quan": 125, "expiry": "12 jan 2022", "brand": "Tata"}, "1032": {"name": "Tata Tea Gold", "price": 48, "quan": 110, "expiry": "3 apr 2023", "brand": "Tata"}, "1033": {"name": "Turmeric Powder", "price": 58, "quan": 80, "expiry": "23 jan 2024", "brand": "Tata"}, "1034": {"name": "Quaker Oats", "price": 285, "quan": 60, "expiry": "18 mar 2022", "brand": "Quaker"}, "1035": {"name": "Saffola Active", "price": 207, "quan": 50, "expiry": "19 jun 2022", "brand": "Saffola"}}

# %%
products
# Out:
# {'1001': {'name': 'Colgate visible white',
#   'price': 240,
#   'quan': 76,
#   'expiry': '19 jul 2024',
#   'brand': 'Colgate'},
#  '1002': {'name': 'Pepsodent Gum Care',
#   'price': 170,
#   'quan': 190,
#   'expiry': '29 sep 2023',
#   'brand': 'Pepsodent'},
#  '1003': {'name': 'Dabur Honey',
#   'price': 210,
#   'quan': 140,
#   'expiry': '15 mar 2024',
#   'brand': 'DABUR'},
#  '1004': {'name': "Nivea Men's Face Wash",
#   'price': 149,
#   'quan': 99,
#   'expiry': '17 aug 2022',
#   'brand': 'Nivea'},
#  '1005': {'name': 'Himalaya Herbal Face wash',
#   'price': 90,
#   'quan': 206,
#   'expiry': '26 jul 2022',
#   'brand': 'Himalaya'},
#  '1006': {'name': "johnson's Baby Powder",
#   'price': 189,
#   'quan': 130,
#   'expiry': '30 aug 2024',
#   'brand': "johnson's"},
#  '1007': {'name': 'Nivea lotion',
#   'price': 135,
#   'quan': 95,
#   'expiry': '13 mar 2024',
#   'brand': 'Nivea'},
#  '1008': {'name': 'Fogg Scent',
#   'price': 259,
#   'quan': 104,
# ...

# %%
import json

# %%
js = json.dumps(products)

# %%
fd = open("products.json",'w')
fd.write(js)
fd.close
# Out:
# <function TextIOWrapper.close()>

# %%
import json

fd = open("products.json",'r')
r = fd.read()
fd.close()

products = json.loads(r)

print("Welcome to Super-Market")


ui_prod = input("Enter the product Id: ")
ui_quan = int(input("Enter the quantity of the Product: "))

for i in products.keys():
    while ui_prod == i:
        if ui_quan <= products[i]['quan']:
            print("****************************************")
            print(" Product             :",products[ui_prod]['name'])
            print(" Price               :",products[ui_prod]['price'])
            print(" Expiry date         :",products[ui_prod]['expiry'])
            print(" Manufacturing Brand :",products[ui_prod]['brand'])
            print("****************************************")
            print("----------BILLING DETAILS:---------- ")
            print("          Total Amount: ",products[ui_prod]['price']*ui_quan) 
            print("          Enjoy Your Day")
            print("      Thank You. Visit Again")
            print("**********************************")
            products[ui_prod]["quan"] = products[ui_prod]["quan"] - ui_quan
        else:
            print("Sorry. Stock of product you enterd is: ",products[ui_prod]['quan'],"\nPlease accept our apologies for this inconvenience")
        break
if ui_prod not in products.keys():
    print("Sorry. No product found for ID: ",ui_prod,"\Please enter valid product ID")
    
import json

js = json.dumps(products)

fd = open("sales.json",'w')
fd.write(js)
fd.close()

## The sold items information is stored on sales.json
fd = open("sales.json",'r')
trans = fd.read()
fd.close()

sales = json.loads(trans)
num = len(sales)+1

sales[num] = {'prod':ui_prod, 'quann' : ui_quan, 'amount': products[ui_prod]['price'] * ui_quan}
sale = json.dumps(sales)

fd = open("sales.json",'w')
fd.write(sale)
fd.close()
# Out:
# Welcome to Super-Market
# Enter the product Id: 1019
# Enter the quantity of the Product: 26
# ****************************************
#  Product             : Cadbury Oreo chacolate
#  Price               : 60
#  Expiry date         : 13 jan 2022
#  Manufacturing Brand : Cadbury
# ****************************************
# ----------BILLING DETAILS:----------
#           Total Amount:  1560
#           Enjoy Your Day
#       Thank You. Visit Again
# **********************************

# %% [markdown]
# # UPDATING INVENTORY AFTER THE PRODUCT IS SOLD

# %%
sales = {1 : {'prod':ui_prod, 'quan':ui_quan, 'amount':products[ui_prod]['price']*ui_quan}}
sal = json.dumps(sales)

fd = open("sales.json",'w')
fd.write(sal)
fd.close()

# %% [markdown]
# # ADDING NEW PRODUCTS TO THE INVENTORY

# %%
prod_id = input("Enter the Product ID : ")
name = input("Enter the Name of the Product : ")
price = int(input("Enter the price per Item : "))
quan = int(input("Enter The Quantity of the Product you want to add to the inventory : "))
expiry = input("Enter the expiry date of the Product : ")
brand = input("Enter the Brand of the product : ")

products[prod_id] = {"name":name,"price":price,"quan":quan,"expiry":expiry,"brand":brand}

js = json.dumps(products)

fd = open("products.json","w")
fd.write(js)
fd.close()
# Out:
# Enter the Product ID : 1006
# Enter the Name of the Product : johnson's baby powder
# Enter the price per Item : 90
# Enter The Quantity of the Product you want to add to the inventory : 150
# Enter the expiry date of the Product : 20 aug 2024
# Enter the Brand of the product : johnson's

# %%
products
# Out:
# {'1001': {'name': 'Colgate visible white',
#   'price': 240,
#   'quan': 76,
#   'expiry': '19 jul 2024',
#   'brand': 'Colgate'},
#  '1002': {'name': 'Pepsodent Gum Care',
#   'price': 170,
#   'quan': 190,
#   'expiry': '29 sep 2023',
#   'brand': 'Pepsodent'},
#  '1003': {'name': 'Dabur Honey',
#   'price': 210,
#   'quan': 140,
#   'expiry': '15 mar 2024',
#   'brand': 'DABUR'},
#  '1004': {'name': "Nivea Men's Face Wash",
#   'price': 149,
#   'quan': 99,
#   'expiry': '17 aug 2022',
#   'brand': 'Nivea'},
#  '1005': {'name': 'Himalaya Herbal Face wash',
#   'price': 90,
#   'quan': 206,
#   'expiry': '26 jul 2022',
#   'brand': 'Himalaya'},
#  '1006': {'name': "johnson's baby powder",
#   'price': 90,
#   'quan': 150,
#   'expiry': '20 aug 2024',
#   'brand': "johnson's"},
#  '1007': {'name': 'Nivea lotion',
#   'price': 135,
#   'quan': 95,
#   'expiry': '13 mar 2024',
#   'brand': 'Nivea'},
#  '1008': {'name': 'Fogg Scent',
#   'price': 259,
#   'quan': 104,
# ...
